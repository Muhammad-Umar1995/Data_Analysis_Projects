# %% [markdown]
# #### 1: Import pandas, matplotlib library, Also using %matpotlib magic command write the paamete which an print the chart

# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# #### 2: Read the csv file and create pandas dataframe object airbnb

# %%
df = pd.read_csv('airbnb prices.csv')
df.head()
# Out:
#     room_id  survey_id   host_id        room_type       city  \
# 0   8177992       1476  20577965  Entire home/apt  Amsterdam
# 1  13925001       1476  38835892     Private room  Amsterdam
# 2   3803882       1476  19545944  Entire home/apt  Amsterdam
# 3  11147683       1476  34203893     Private room  Amsterdam
# 4  16565978       1476   1446243  Entire home/apt  Amsterdam
#
#                              neighborhood  reviews  overall_satisfaction  \
# 0  Oostelijk Havengebied / Indische Buurt        6                     5
# 1                 De Pijp / Rivierenbuurt        3                     5
# 2                         Bijlmer Centrum        1                     0
# 3                           Bos en Lommer        4                     5
# 4                            Centrum Oost        0                     0
#
#    accommodates  bedrooms  price  \
# 0             3         1   12.0
# 1             1         1   21.0
# 2             3         1   22.0
# ...

# %%
df.tail()
# Out:
#         room_id  survey_id    host_id        room_type       city  \
# 17455  19408111       1476   47078997  Entire home/apt  Amsterdam
# 17456  17377934       1476  117439187  Entire home/apt  Amsterdam
# 17457  16344025       1476  104389329  Entire home/apt  Amsterdam
# 17458  15626614       1476   60409350  Entire home/apt  Amsterdam
# 17459  12837950       1476   22855069  Entire home/apt  Amsterdam
#
#                   neighborhood  reviews  overall_satisfaction  accommodates  \
# 17455             Centrum West        0                     0             4
# 17456  Geuzenveld / Slotermeer        0                     0             2
# 17457             Centrum West        6                     5            16
# 17458             Centrum Oost        0                     0            16
# 17459               Westerpark        0                     0             2
#
#        bedrooms   price                                               name  \
# ...

# %% [markdown]
# #### 3: Review first 5 rows

# %%
df.head(5)
# Out:
#     room_id  survey_id   host_id        room_type       city  \
# 0   8177992       1476  20577965  Entire home/apt  Amsterdam
# 1  13925001       1476  38835892     Private room  Amsterdam
# 2   3803882       1476  19545944  Entire home/apt  Amsterdam
# 3  11147683       1476  34203893     Private room  Amsterdam
# 4  16565978       1476   1446243  Entire home/apt  Amsterdam
#
#                              neighborhood  reviews  overall_satisfaction  \
# 0  Oostelijk Havengebied / Indische Buurt        6                     5
# 1                 De Pijp / Rivierenbuurt        3                     5
# 2                         Bijlmer Centrum        1                     0
# 3                           Bos en Lommer        4                     5
# 4                            Centrum Oost        0                     0
#
#    accommodates  bedrooms  price  \
# 0             3         1   12.0
# 1             1         1   21.0
# 2             3         1   22.0
# ...

# %% [markdown]
# #### 4: What are the room_type available

# %%
df["room_type"].unique()
# Out:
# array(['Entire home/apt', 'Private room'], dtype=object)

# %%
df.value_counts('room_type')
# Out:
# room_type
# Entire home/apt    14090
# Private room        3370
# dtype: int64

# %% [markdown]
# #### 5: Drop Shared room type as its count is very low compare to others

# %%
df_new = df[df.room_type != 'Shared room']
df_new
# Out:
#         room_id  survey_id    host_id        room_type       city  \
# 0       8177992       1476   20577965  Entire home/apt  Amsterdam
# 1      13925001       1476   38835892     Private room  Amsterdam
# 2       3803882       1476   19545944  Entire home/apt  Amsterdam
# 3      11147683       1476   34203893     Private room  Amsterdam
# 4      16565978       1476    1446243  Entire home/apt  Amsterdam
# ...         ...        ...        ...              ...        ...
# 17455  19408111       1476   47078997  Entire home/apt  Amsterdam
# 17456  17377934       1476  117439187  Entire home/apt  Amsterdam
# 17457  16344025       1476  104389329  Entire home/apt  Amsterdam
# 17458  15626614       1476   60409350  Entire home/apt  Amsterdam
# 17459  12837950       1476   22855069  Entire home/apt  Amsterdam
#
#                                  neighborhood  reviews  overall_satisfaction  \
# 0      Oostelijk Havengebied / Indische Buurt        6                     5
# ...

# %%
df_new.value_counts('room_type')
# Out:
# room_type
# Entire home/apt    14090
# Private room        3370
# dtype: int64

# %% [markdown]
# #### 6: Take a count of each neighborhood to show how popular they are w.r.t to airbnb apartment number

# %%
df_new.value_counts('neighborhood')
# Out:
# neighborhood
# De Baarsjes / Oud West                    3138
# De Pijp / Rivierenbuurt                   2221
# Centrum West                              1962
# Centrum Oost                              1585
# Noord-West / Noord-Midden                 1380
# Westerpark                                1348
# Oud Oost                                  1121
# Bos en Lommer                              919
# Oostelijk Havengebied / Indische Buurt     870
# Oud Noord                                  456
# Watergraafsmeer                            427
# Ijburg / Eiland Zeeburg                    356
# Slotervaart                                327
# Buitenveldert / Zuidas                     239
# Noord West                                 232
# Noord Oost                                 214
# Geuzenveld / Slotermeer                    180
# Osdorp                                     154
# De Aker / Nieuw Sloten                     104
# Bijlmer Oost                                91
# ...

# %% [markdown]
# #### 7: Number of reviews that is given to ex. How many property has just 0 review or 1 etc

# %%
df_new.value_counts('reviews')
# Out:
# reviews
# 0      2769
# 1      1410
# 2      1171
# 3      1045
# 4       871
#        ...
# 225       1
# 224       1
# 223       1
# 220       1
# 532       1
# Length: 277, dtype: int64

# %% [markdown]
# #### 8: What is the overall_satisfaction count by each rating

# %%
df.value_counts('overall_satisfaction')
# Out:
# overall_satisfaction
# 5    11468
# 0     5358
# 4      617
# 3       16
# 1        1
# dtype: int64

# %% [markdown]
# #### 9: Create a sub dataset where overall satisfaction is 0

# %%
zero_satisfaction = df[df.overall_satisfaction == 0]
zero_satisfaction
# Out:
#         room_id  survey_id    host_id        room_type       city  \
# 2       3803882       1476   19545944  Entire home/apt  Amsterdam
# 4      16565978       1476    1446243  Entire home/apt  Amsterdam
# 8      13760329       1476   80676239     Private room  Amsterdam
# 10     12886265       1476   50843183     Private room  Amsterdam
# 15      7447719       1476   34158425     Private room  Amsterdam
# ...         ...        ...        ...              ...        ...
# 17453  10511291       1476    5421078  Entire home/apt  Amsterdam
# 17455  19408111       1476   47078997  Entire home/apt  Amsterdam
# 17456  17377934       1476  117439187  Entire home/apt  Amsterdam
# 17458  15626614       1476   60409350  Entire home/apt  Amsterdam
# 17459  12837950       1476   22855069  Entire home/apt  Amsterdam
#
#                     neighborhood  reviews  overall_satisfaction  accommodates  \
# 2                Bijlmer Centrum        1                     0             3
# ...

# %% [markdown]
# #### 10: Describe this dataset using describe command and write your observation

# %%
df_new.describe
# Out:
# <bound method NDFrame.describe of         room_id  survey_id    host_id        room_type       city  \
# 0       8177992       1476   20577965  Entire home/apt  Amsterdam
# 1      13925001       1476   38835892     Private room  Amsterdam
# 2       3803882       1476   19545944  Entire home/apt  Amsterdam
# 3      11147683       1476   34203893     Private room  Amsterdam
# 4      16565978       1476    1446243  Entire home/apt  Amsterdam
# ...         ...        ...        ...              ...        ...
# 17455  19408111       1476   47078997  Entire home/apt  Amsterdam
# 17456  17377934       1476  117439187  Entire home/apt  Amsterdam
# 17457  16344025       1476  104389329  Entire home/apt  Amsterdam
# 17458  15626614       1476   60409350  Entire home/apt  Amsterdam
# 17459  12837950       1476   22855069  Entire home/apt  Amsterdam
#
#                                  neighborhood  reviews  overall_satisfaction  \
# ...
